# %%
import pandas as pd
import requests 
import json
import pprint
import psycopg2

from bs4 import BeautifulSoup

from sqlalchemy import create_engine

# %%
headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
 'Accept-Encoding': 'gzip, deflate, br',
 'Accept-Language': 'en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7',
 'Cache-Control': 'max-age=0',
 'Connection': 'keep-alive',
 'Host': 'www.yellowpages.com',
 'Upgrade-Insecure-Requests': '1',
 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
 }

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee+shops&geo_location_terms=Philadelphia%2C+PA',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
business_name = []
badges = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name.append(name.span.text.strip())

# %%
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges.append(name.text.strip())

# %%
yellowpagesdf = pd.DataFrame(
    {'business_name': business_name,
     'badges': badges,
    })
yellowpagesdf
# Out:
#                     business_name                  badges
# 0                  Sabrina's Cafe  Philadelphia, PA 19147
# 1                     Monk's Cafe  Philadelphia, PA 19102
# 2                   Cafe La Maude  Philadelphia, PA 19123
# 3                   Morning Glory  Philadelphia, PA 19147
# 4                     Miles Table  Philadelphia, PA 19146
# 5     Chapterhouse Cafe & Gallery  Philadelphia, PA 19147
# 6                   Mood Cafe Inc  Philadelphia, PA 19143
# 7                      Hinge Cafe  Philadelphia, PA 19134
# 8                Menagerie Coffee  Philadelphia, PA 19106
# 9                       Cafe Lift  Philadelphia, PA 19123
# 10     Sabrina's Cafe At Powelton  Philadelphia, PA 19104
# 11                  Nifty Fifty's  Philadelphia, PA 19114
# 12                       Rim Cafe  Philadelphia, PA 19147
# 13         Greenstreet Coffee Co.  Philadelphia, PA 19107
# 14               Coffee House Too  Philadelphia, PA 19125
# ...

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=2',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
business_name2 = []
badges2 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name2.append(name.span.text.strip())

# %%
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges2.append(name.text.strip())

# %%
yellowpagesdf2 = pd.DataFrame(
    {'business_name': business_name2,
     'badges': badges2,
    })
yellowpagesdf2
# Out:
#                 business_name                  badges
# 0        Cafe Loftus Downtown  Philadelphia, PA 19102
# 1                Cafe De Laos  Philadelphia, PA 19147
# 2   Point of Destination Cafe  Philadelphia, PA 19119
# 3        Mugshots Coffeehouse  Philadelphia, PA 19130
# 4                   La Cigale  Philadelphia, PA 19103
# 5           Trio Delight Cafe  Philadelphia, PA 19120
# 6                 Miles Table  Philadelphia, PA 19146
# 7                       Rally  Philadelphia, PA 19147
# 8                    Rim Cafe  Philadelphia, PA 19147
# 9                Benna's Cafe  Philadelphia, PA 19147
# 10                  Buzz Cafe  Philadelphia, PA 19122
# 11           Coffee House Too  Philadelphia, PA 19125
# 12               Tim Horton's  Philadelphia, PA 19148
# 13              Pret a Manger  Philadelphia, PA 19102
# 14  Tuscany Cafe Broad Street  Philadelphia, PA 19102
# 15                  Cafe Lift  Philadelphia, PA 19123
# ...

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=3',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
business_name3 = []
badges3 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name3.append(name.span.text.strip())

# %%
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges3.append(name.text.strip())

# %%
yellowpagesdf3 = pd.DataFrame(
    {'business_name': business_name3,
     'badges': badges3,
    })
yellowpagesdf3
# Out:
#                 business_name                  badges
# 0                Tim Horton's  Philadelphia, PA 19148
# 1            Starbucks Coffee  Philadelphia, PA 19131
# 2               Pret a Manger  Philadelphia, PA 19102
# 3   Tuscany Cafe Broad Street  Philadelphia, PA 19102
# 4                   Cafe Lift  Philadelphia, PA 19123
# 5                      Yeeroh  Philadelphia, PA 19146
# 6                 Rosa Blanca  Philadelphia, PA 19106
# 7           Kawaii Kitty Cafe  Philadelphia, PA 19147
# 8    Little Pete's Restaurant  Philadelphia, PA 19130
# 9                    Cafe Ida  Philadelphia, PA 19145
# 10                 Coffeeserv  Philadelphia, PA 19129
# 11         Under The Oak Cafe  Philadelphia, PA 19126
# 12              Cafe Expresso  Philadelphia, PA 19135
# 13        Three Monkey's Cafe  Philadelphia, PA 19114
# 14           Starbucks Coffee  Philadelphia, PA 19102
# 15           Starbucks Coffee  Philadelphia, PA 19107
# ...

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=4',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
business_name4 = []
badges4 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name4.append(name.span.text.strip())

# %%
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges4.append(name.text.strip())

# %%
yellowpagesdf4 = pd.DataFrame(
    {'business_name': business_name4,
     'badges': badges4,
    })
yellowpagesdf4
# Out:
#                  business_name                  badges
# 0                Saxbys Coffee  Philadelphia, PA 19107
# 1                   Joe Coffee  Philadelphia, PA 19103
# 2       Greenstreet Coffee Co.  Philadelphia, PA 19107
# 3             Starbucks Coffee  Philadelphia, PA 19107
# 4             Starbucks Coffee  Philadelphia, PA 19103
# 5                 Bodhi Coffee  Philadelphia, PA 19107
# 6                   Leila Cafe  Philadelphia, PA 19147
# 7                       Cafe-V  Philadelphia, PA 19147
# 8                Ultimo Coffee  Philadelphia, PA 19103
# 9                       L'aube  Philadelphia, PA 19146
# 10           Little Spoon Cafe  Philadelphia, PA 19146
# 11             928 Pine Caffee  Philadelphia, PA 19107
# 12            Starbucks Coffee  Philadelphia, PA 19106
# 13              Next Door Cafe  Philadelphia, PA 19106
# 14         Caffeination Coffee  Philadelphia, PA 19103
# 15               Walnut Coffee  Philadelphia, PA 19106
# ...

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=5',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
business_name5 = []
badges5 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name5.append(name.span.text.strip())
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges5.append(name.text.strip())
yellowpagesdf5 = pd.DataFrame(
    {'business_name': business_name5,
     'badges': badges5,
    })
# Out:
#                   business_name                  badges
# 0      Doubleshots Espresso Bar  Philadelphia, PA 19106
# 1                 Saxbys Coffee  Philadelphia, PA 19106
# 2            Beirut Cafe&Hookah  Philadelphia, PA 19147
# 3             Shot Tower Coffee  Philadelphia, PA 19147
# 4                    Hoof & Fin  Philadelphia, PA 19147
# 5                   Sphinx Cafe  Philadelphia, PA 19106
# 6                      Ocf Cafe  Philadelphia, PA 19146
# 7                  Red Cup Cafe  Philadelphia, PA 19123
# 8              Ocf Coffee House  Philadelphia, PA 19147
# 9              Starbucks Coffee  Philadelphia, PA 19104
# 10          Peet's Coffee & Tea  Philadelphia, PA 19147
# 11                   Joe Coffee  Philadelphia, PA 19104
# 12                Saxbys Coffee  Philadelphia, PA 19104
# 13                  Bardot Cafe  Philadelphia, PA 19123
# 14         Philadelphia Java Co  Philadelphia, PA 19147
# 15          Brown Street Coffee  Philadelphia, PA 19130
# ...

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=6',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
business_name6 = []
badges6 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name6.append(name.span.text.strip())
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges6.append(name.text.strip())
yellowpagesdf6 = pd.DataFrame(
    {'business_name': business_name6,
     'badges': badges6,
    })

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=7',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
business_name7 = []
badges7 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name7.append(name.span.text.strip())
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges7.append(name.text.strip())
yellowpagesdf7 = pd.DataFrame(
    {'business_name': business_name7,
     'badges': badges7,
    })

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=8',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
business_name8 = []
badges8 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name8.append(name.span.text.strip())
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges8.append(name.text.strip())
yellowpagesdf8 = pd.DataFrame(
    {'business_name': business_name8,
     'badges': badges8,
    })

# %%
response = requests.get('https://www.yellowpages.com/search?search_terms=coffee%20shops&geo_location_terms=Philadelphia%2C%20PA&page=9',headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
business_name9 = []
badges9 = []
for names in soup.findAll('div',{'class':'search-results organic'}):
    for name in names.findAll('a',{'class':'business-name'}):
        business_name9.append(name.span.text.strip())
for name in soup.findAll('div',{'class':'v-card','class': 'locality'}):
        badges9.append(name.text.strip())
yellowpagesdf9 = pd.DataFrame(
    {'business_name': business_name9,
     'badges': badges9,
    })

# %%
coffee_yp_df = pd.concat([yellowpagesdf, yellowpagesdf2, yellowpagesdf3, yellowpagesdf4, yellowpagesdf5, yellowpagesdf6, yellowpagesdf7, yellowpagesdf8, yellowpagesdf9])
# Out:
#               business_name                  badges
# 0            Sabrina's Cafe  Philadelphia, PA 19147
# 1               Monk's Cafe  Philadelphia, PA 19102
# 2             Cafe La Maude  Philadelphia, PA 19123
# 3             Morning Glory  Philadelphia, PA 19147
# 4               Miles Table  Philadelphia, PA 19146
# ..                      ...                     ...
# 25                     Cosi  Philadelphia, PA 19104
# 26  Flannel Cookin' Country  Philadelphia, PA 19148
# 27                Ace Diner  Philadelphia, PA 19131
# 28           Factory Donuts  Philadelphia, PA 19135
# 29                  Dunkin'  Philadelphia, PA 19142
#
# [270 rows x 2 columns]

# %%
coffee_yp_df.rename(columns = {'business_name' : 'coffee_shop', 'badges' : 'locality'}, inplace = True)

# %%
api_key = "API KEY HERE"

headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

params = {'term':['Coffee Shop'],'location':'Philadelphia','offset':'50','limit':'50'}

req=requests.get(url, params=params, headers=headers)

print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
coffee_json = json.loads(req.text)

# %%
print(coffee_json)
# Out:
# {'businesses': [{'id': 'S1FwTmCAwv5ulu5gToWi_w', 'alias': 'rim-cafe-philadelphia', 'name': 'RIM Cafe', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJgub5JmGSBvNO4BuAg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rim-cafe-philadelphia?adjust_creative=ABvUrR9YLLhULzGEss9gjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ABvUrR9YLLhULzGEss9gjA', 'review_count': 282, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 39.93438, 'longitude': -75.15898}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1172 S 9th St', 'address2': None, 'address3': '', 'city': 'Philadelphia', 'zip_code': '19147', 'country': 'US', 'state': 'PA', 'display_address': ['1172 S 9th St', 'Philadelphia, PA 19147']}, 'phone': '+12154653515', 'display_phone': '(215) 465-3515', 'distance': 2394.6235335792385}, {'id': '9A5Gw0At6so0x-vWM0_JZw', 'alias': 'grindcore-house-philadelphia', 
# ...

# %%
print(json.dumps(coffee_json, indent=2, sort_keys=True))
# Out:
# {
#   "businesses": [
#     {
#       "alias": "rim-cafe-philadelphia",
#       "categories": [
#         {
#           "alias": "coffee",
#           "title": "Coffee & Tea"
#         }
#       ],
#       "coordinates": {
#         "latitude": 39.93438,
#         "longitude": -75.15898
#       },
#       "display_phone": "(215) 465-3515",
#       "distance": 2394.6235335792385,
#       "id": "S1FwTmCAwv5ulu5gToWi_w",
#       "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJgub5JmGSBvNO4BuAg/o.jpg",
#       "is_closed": false,
#       "location": {
#         "address1": "1172 S 9th St",
#         "address2": null,
#         "address3": "",
#         "city": "Philadelphia",
#         "country": "US",
#         "display_address": [
#           "1172 S 9th St",
#           "Philadelphia, PA 19147"
#         ],
#         "state": "PA",
#         "zip_code": "19147"
#       },
#       "name": "RIM Cafe",
#       "phone": "+12154653515",
#       "price": "$$",
# ...

# %%
coffee1_df = pd.DataFrame(coffee_json["businesses"])

# %%
url='https://api.yelp.com/v3/businesses/search'

params = {'term':['Coffee Shop'],'location':'Philadelphia','limit':'50'}

req=requests.get(url, params=params, headers=headers)

print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
coffee_json2 = json.loads(req.text)

# %%
print(json.dumps(coffee_json2, indent=2, sort_keys=True))
# Out:
# {
#   "businesses": [
#     {
#       "alias": "elixr-coffee-roasters-philadelphia-3",
#       "categories": [
#         {
#           "alias": "coffeeroasteries",
#           "title": "Coffee Roasteries"
#         },
#         {
#           "alias": "cafes",
#           "title": "Cafes"
#         }
#       ],
#       "coordinates": {
#         "latitude": 39.9493333402848,
#         "longitude": -75.1667326511781
#       },
#       "display_phone": "",
#       "distance": 624.4594152381294,
#       "id": "oqbhVgliVJH-iRa3AnD-3A",
#       "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/iJxpSky6UGtsmT_gQ8BbOQ/o.jpg",
#       "is_closed": false,
#       "location": {
#         "address1": "207 S Sydenham St",
#         "address2": "",
#         "address3": "",
#         "city": "Philadelphia",
#         "country": "US",
#         "display_address": [
#           "207 S Sydenham St",
#           "Philadelphia, PA 19102"
#         ],
#         "state": "PA",
# ...

# %%
coffee2_df = pd.DataFrame(coffee_json2["businesses"])

# %%
url='https://api.yelp.com/v3/businesses/search'

params = {'term':['Coffee Shop'],'location':'Philadelphia','offset':'100','limit':'50'}

req=requests.get(url, params=params, headers=headers)

print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
coffee_json3 = json.loads(req.text)

# %%
print(json.dumps(coffee_json3, indent=2, sort_keys=True))
# Out:
# {
#   "businesses": [
#     {
#       "alias": "rally-philadelphia",
#       "categories": [
#         {
#           "alias": "coffee",
#           "title": "Coffee & Tea"
#         },
#         {
#           "alias": "venues",
#           "title": "Venues & Event Spaces"
#         }
#       ],
#       "coordinates": {
#         "latitude": 39.9412,
#         "longitude": -75.15388
#       },
#       "display_phone": "(215) 925-3657",
#       "distance": 2023.7232184865466,
#       "id": "yIIibdtcOnGsjtvgNuBqKA",
#       "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/49ZeMq83RPOaij_gCRUoYQ/o.jpg",
#       "is_closed": false,
#       "location": {
#         "address1": "701 S 7th St",
#         "address2": "",
#         "address3": "",
#         "city": "Philadelphia",
#         "country": "US",
#         "display_address": [
#           "701 S 7th St",
#           "Philadelphia, PA 19147"
#         ],
#         "state": "PA",
#         "zip_code": "19147"
#       },
# ...

# %%
coffee3_df = pd.DataFrame(coffee_json3["businesses"])

# %%
coffee_comb_df = pd.concat([coffee1_df, coffee2_df, coffee3_df])
coffee_comb_df.head()
# Out:
#                        id                              alias  \
# 0  S1FwTmCAwv5ulu5gToWi_w              rim-cafe-philadelphia
# 1  9A5Gw0At6so0x-vWM0_JZw       grindcore-house-philadelphia
# 2  QTjtz-bfm8Yrrv6t0PP0FQ       knockbox-cafe-philadelphia-2
# 3  pq8x9lii-ZV1U4RJVG29Lg   la-colombe-coffee-philadelphia-4
# 4  hKfs-tsper4UuAOiG23z2A  two-persons-coffee-philadelphia-2
#
#                  name                                          image_url  \
# 0            RIM Cafe  https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJg...
# 1     Grindcore House  https://s3-media3.fl.yelpcdn.com/bphoto/sb3Yiz...
# 2       Knockbox Cafe  https://s3-media2.fl.yelpcdn.com/bphoto/C2XEcw...
# 3   La Colombe Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/Fx1FQm...
# 4  Two Persons Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/QrTUoW...
#
#    is_closed                                                url  review_count  \
# ...

# %%
coffee_comb_df.rename(columns = {'id' : 'id', 'alias' : 'alias', 'name': 'coffee_shop', 'image_url': 'image', 'is_close':'closed', 'url':'url', 'review_count':'review_count', 'categories':'categories'}, inplace = True)

# %%
coffee_comb_df
# Out:
#                         id                              alias  \
# 0   S1FwTmCAwv5ulu5gToWi_w              rim-cafe-philadelphia
# 1   9A5Gw0At6so0x-vWM0_JZw       grindcore-house-philadelphia
# 2   QTjtz-bfm8Yrrv6t0PP0FQ       knockbox-cafe-philadelphia-2
# 3   pq8x9lii-ZV1U4RJVG29Lg   la-colombe-coffee-philadelphia-4
# 4   hKfs-tsper4UuAOiG23z2A  two-persons-coffee-philadelphia-2
# ..                     ...                                ...
# 45  opjF_JN6Kpr5zWxBhkGC7w        mammoth-coffee-philadelphia
# 46  -k1iNvlyQZkZ14Hcqzlk4Q          the-pharmacy-philadelphia
# 47  Ay0j65KKb3sOrOFUVWs44g       dolce-and-caffè-philadelphia
# 48  LkasU7-347mpSm3erAQHyA    walnut-street-cafe-philadelphia
# 49  i6jA8vSHrP9LiUPHlqPVwA            cafe-olé-philadelphia-2
#
#            coffee_shop                                              image  \
# 0             RIM Cafe  https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJg...
# ...

# %%
combined_df = pd.merge(coffee_comb_df, coffee_yp_df, on='coffee_shop', how='outer')

# %%
combined_df.head()
# Out:
#                        id                             alias  \
# 0  S1FwTmCAwv5ulu5gToWi_w             rim-cafe-philadelphia
# 1  9A5Gw0At6so0x-vWM0_JZw      grindcore-house-philadelphia
# 2  QTjtz-bfm8Yrrv6t0PP0FQ      knockbox-cafe-philadelphia-2
# 3  pq8x9lii-ZV1U4RJVG29Lg  la-colombe-coffee-philadelphia-4
# 4  htO_nlxkEsYHzDrtbiUxew  la-colombe-coffee-philadelphia-2
#
#          coffee_shop                                              image  \
# 0           RIM Cafe  https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJg...
# 1    Grindcore House  https://s3-media3.fl.yelpcdn.com/bphoto/sb3Yiz...
# 2      Knockbox Cafe  https://s3-media2.fl.yelpcdn.com/bphoto/C2XEcw...
# 3  La Colombe Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/Fx1FQm...
# 4  La Colombe Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/vpt-WO...
#
#   is_closed                                                url  review_count  \
# 0     False  https://www.yelp.com/biz/rim-cafe-philadelphia...         282.0
# ...

# %%
combined_df['coffee_shop'] = combined_df['coffee_shop'].str.upper()

# %%
combined_df.head()
# Out:
#                        id                             alias  \
# 0  S1FwTmCAwv5ulu5gToWi_w             rim-cafe-philadelphia
# 1  9A5Gw0At6so0x-vWM0_JZw      grindcore-house-philadelphia
# 2  QTjtz-bfm8Yrrv6t0PP0FQ      knockbox-cafe-philadelphia-2
# 3  pq8x9lii-ZV1U4RJVG29Lg  la-colombe-coffee-philadelphia-4
# 4  htO_nlxkEsYHzDrtbiUxew  la-colombe-coffee-philadelphia-2
#
#          coffee_shop                                              image  \
# 0           RIM CAFE  https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJg...
# 1    GRINDCORE HOUSE  https://s3-media3.fl.yelpcdn.com/bphoto/sb3Yiz...
# 2      KNOCKBOX CAFE  https://s3-media2.fl.yelpcdn.com/bphoto/C2XEcw...
# 3  LA COLOMBE COFFEE  https://s3-media1.fl.yelpcdn.com/bphoto/Fx1FQm...
# 4  LA COLOMBE COFFEE  https://s3-media1.fl.yelpcdn.com/bphoto/vpt-WO...
#
#   is_closed                                                url  review_count  \
# 0     False  https://www.yelp.com/biz/rim-cafe-philadelphia...         282.0
# ...

# %%
license_file = "./Resources/business_licenses.csv"
license_df = pd.read_csv(license_file)
license_df.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                             the_geom  \
# 0  0101000020E61000002302E95940CD52C01C1F517B21F9...
# 1  0101000020E6100000A8DB44507FC952C09AE75B74FF02...
# 2  0101000020E6100000291B3D0A7CCE52C0572AFB4C79FA...
# 3  0101000020E6100000E08BF141D0CA52C09938A9CAF6F6...
# 4  0101000020E610000097E20A4531CB52C0BFCCFFE20EF6...
#
#                                 the_geom_webmercator  objectid  \
# 0  0101000020110F00000D40C8B3CAEF5FC150A641B24888...        29
# 1  0101000020110F00003A3279486AE95FC1E1855A943893...        30
# 2  0101000020110F000036D972EEE2F15FC13FD7D09CC589...        31
# 3  0101000020110F0000AF4BD09DA6EB5FC13B9E9747E285...        32
# 4  0101000020110F0000DF77BA664BEC5FC18EF10273E184...        33
#
# ...

# %%
license_df.rename(columns = {'business_name' : 'coffee_shop'}, inplace = True)

# %%
license_df
# Out:
#                                                  the_geom  \
# 0       0101000020E61000002302E95940CD52C01C1F517B21F9...
# 1       0101000020E6100000A8DB44507FC952C09AE75B74FF02...
# 2       0101000020E6100000291B3D0A7CCE52C0572AFB4C79FA...
# 3       0101000020E6100000E08BF141D0CA52C09938A9CAF6F6...
# 4       0101000020E610000097E20A4531CB52C0BFCCFFE20EF6...
# ...                                                   ...
# 354460  0101000020E61000009A7D2AE877CD52C03E5E194931F9...
# 354461  0101000020E61000003CB9171695C952C0B7656FD733F7...
# 354462  0101000020E610000046C1A0D56CC952C0CF11019C02F7...
# 354463  0101000020E61000003BC1146C5EC752C073FD013D5A02...
# 354464  0101000020E610000056B5B98571C952C0DB10BF5004F7...
#
#                                      the_geom_webmercator  objectid  \
# 0       0101000020110F00000D40C8B3CAEF5FC150A641B24888...        29
# 1       0101000020110F00003A3279486AE95FC1E1855A943893...        30
# ...

# %%
all_combined_df = pd.merge(combined_df, license_df, on='coffee_shop', how='outer')

# %%
all_combined_df
# Out:
#                             id                         alias  \
# 0       S1FwTmCAwv5ulu5gToWi_w         rim-cafe-philadelphia
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3       9A5Gw0At6so0x-vWM0_JZw  grindcore-house-philadelphia
# 4       QTjtz-bfm8Yrrv6t0PP0FQ  knockbox-cafe-philadelphia-2
# ...                        ...                           ...
# 354923                     NaN                           NaN
# 354924                     NaN                           NaN
# 354925                     NaN                           NaN
# 354926                     NaN                           NaN
# 354927                     NaN                           NaN
#
#                   coffee_shop  \
# 0                    RIM CAFE
# 1                    RIM CAFE
# 2                    RIM CAFE
# 3             GRINDCORE HOUSE
# 4               KNOCKBOX CAFE
# ...                       ...
# ...

# %%
new_combined_df = all_combined_df[all_combined_df['id'].notna()]

# %%
new_combined_df
# Out:
#                          id                             alias  \
# 0    S1FwTmCAwv5ulu5gToWi_w             rim-cafe-philadelphia
# 3    9A5Gw0At6so0x-vWM0_JZw      grindcore-house-philadelphia
# 4    QTjtz-bfm8Yrrv6t0PP0FQ      knockbox-cafe-philadelphia-2
# 5    pq8x9lii-ZV1U4RJVG29Lg  la-colombe-coffee-philadelphia-4
# 6    htO_nlxkEsYHzDrtbiUxew  la-colombe-coffee-philadelphia-2
# ..                      ...                               ...
# 323  opjF_JN6Kpr5zWxBhkGC7w       mammoth-coffee-philadelphia
# 324  -k1iNvlyQZkZ14Hcqzlk4Q         the-pharmacy-philadelphia
# 325  Ay0j65KKb3sOrOFUVWs44g      dolce-and-caffè-philadelphia
# 326  LkasU7-347mpSm3erAQHyA   walnut-street-cafe-philadelphia
# 327  i6jA8vSHrP9LiUPHlqPVwA           cafe-olé-philadelphia-2
#
#             coffee_shop                                              image  \
# 0              RIM CAFE  https://s3-media3.fl.yelpcdn.com/bphoto/lKuWJg...
# ...

# %%
final_combined_df = new_combined_df[['coffee_shop', 'is_closed', 'review_count', 'rating', 'transactions', 'price', 'address', 'display_phone', 'zip', 'locality', 'opa_owner', 'licensetype', 'lat', 'lng']].copy()

# %%
final_combined_df
# Out:
#             coffee_shop is_closed  review_count  rating        transactions  \
# 0              RIM CAFE     False         282.0     4.5  [delivery, pickup]
# 3       GRINDCORE HOUSE     False         332.0     4.5          [delivery]
# 4         KNOCKBOX CAFE     False         111.0     4.0          [delivery]
# 5     LA COLOMBE COFFEE     False         147.0     4.0          [delivery]
# 6     LA COLOMBE COFFEE     False         593.0     4.0          [delivery]
# ..                  ...       ...           ...     ...                 ...
# 323      MAMMOTH COFFEE     False          30.0     4.0  [pickup, delivery]
# 324        THE PHARMACY     False          24.0     2.5  [pickup, delivery]
# 325       DOLCE & CAFFÈ     False          99.0     4.5  [pickup, delivery]
# 326  WALNUT STREET CAFE     False         220.0     3.5  [pickup, delivery]
# 327            CAFE OLÉ     False         365.0     4.0  [pickup, delivery]
#
# ...

# %%
final_combined_df.drop_duplicates(subset ="display_phone",
                     keep = False, inplace = True)

# %%
final_combined_df.reset_index(drop=True)
# Out:
#             coffee_shop is_closed  review_count  rating        transactions  \
# 0              RIM CAFE     False         282.0     4.5  [delivery, pickup]
# 1       GRINDCORE HOUSE     False         332.0     4.5          [delivery]
# 2         KNOCKBOX CAFE     False         111.0     4.0          [delivery]
# 3     LA COLOMBE COFFEE     False         147.0     4.0          [delivery]
# 4     LA COLOMBE COFFEE     False         593.0     4.0          [delivery]
# ..                  ...       ...           ...     ...                 ...
# 96       MAMMOTH COFFEE     False          30.0     4.0  [pickup, delivery]
# 97         THE PHARMACY     False          24.0     2.5  [pickup, delivery]
# 98        DOLCE & CAFFÈ     False          99.0     4.5  [pickup, delivery]
# 99   WALNUT STREET CAFE     False         220.0     3.5  [pickup, delivery]
# 100            CAFE OLÉ     False         365.0     4.0  [pickup, delivery]
#
# ...

# %%
final_combined_df
# Out:
#             coffee_shop is_closed  review_count  rating        transactions  \
# 0              RIM CAFE     False         282.0     4.5  [delivery, pickup]
# 3       GRINDCORE HOUSE     False         332.0     4.5          [delivery]
# 4         KNOCKBOX CAFE     False         111.0     4.0          [delivery]
# 5     LA COLOMBE COFFEE     False         147.0     4.0          [delivery]
# 6     LA COLOMBE COFFEE     False         593.0     4.0          [delivery]
# ..                  ...       ...           ...     ...                 ...
# 323      MAMMOTH COFFEE     False          30.0     4.0  [pickup, delivery]
# 324        THE PHARMACY     False          24.0     2.5  [pickup, delivery]
# 325       DOLCE & CAFFÈ     False          99.0     4.5  [pickup, delivery]
# 326  WALNUT STREET CAFE     False         220.0     3.5  [pickup, delivery]
# 327            CAFE OLÉ     False         365.0     4.0  [pickup, delivery]
#
# ...

# %%
final_combined_df.to_csv('./resources/finaltable.csv', index=False)

# %%
connection_string = "postgres:postgres@localhost:5432/coffee_shop_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['coffee_shops']

# %%
final_combined_df.to_sql(name='coffee_shops', con=engine, if_exists='append', index=True)
